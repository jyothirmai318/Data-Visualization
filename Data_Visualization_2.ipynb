# %% [markdown]
# <a href="https://colab.research.google.com/github/jyothirmai318/Data-Visualization/blob/main/Data_Visualization_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# For this, I have used Automobile Dataset for data analysis. This Dataset has different characteristics such as body-style, wheel-base, engine-type, price, mileage, horsepower, etc.

# %%
#cleaning the dataset and replacing null values
import pandas as pd
df = pd.read_csv('Automobile_data.csv')
df.replace(["?", "n.a", "NaN"], None, inplace=True)
cleaned_file_name = 'cleaned_Automobile_data.csv'
df.to_csv(cleaned_file_name, index=False)

# %%
#Highest priced car
df = pd.read_csv('cleaned_Automobile_data.csv')
company_highest_price = df.groupby('company')['price'].max()
print(company_highest_price)
# Out:
# company
# alfa-romero      16500.0
# audi             18920.0
# bmw              41315.0
# chevrolet         6575.0
# dodge             6377.0
# honda            12945.0
# isuzu             6785.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mitsubishi        8189.0
# nissan           13499.0
# porsche          37028.0
# toyota           15750.0
# volkswagen        9995.0
# volvo            13415.0
# Name: price, dtype: float64

# %%
#average mileage of each car making company.
average_mileage = df.groupby('company')['average-mileage'].mean()
print(average_mileage)
# Out:
# company
# alfa-romero      20.333333
# audi             20.000000
# bmw              19.000000
# chevrolet        41.000000
# dodge            31.000000
# honda            26.333333
# isuzu            33.333333
# jaguar           14.333333
# mazda            28.000000
# mercedes-benz    18.000000
# mitsubishi       29.500000
# nissan           31.400000
# porsche          17.000000
# toyota           28.714286
# volkswagen       31.750000
# volvo            23.000000
# Name: average-mileage, dtype: float64

# %% [markdown]
# #####Concatenating two data frames using the following conditions. Create two data frames using the following two dictionaries.
# #####GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
# #####japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925, 71400]}
JapaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi'], 'Price': [29995, 23600, 61500, 58900]}
df_german = pd.DataFrame(GermanCars)
df_japanese = pd.DataFrame(JapaneseCars)
df1= pd.concat([df_german, df_japanese], ignore_index=True)
print(df1)
# Out:
#       Company   Price
# 0        Ford   23845
# 1    Mercedes  171995
# 2         BMV  135925
# 3        Audi   71400
# 4      Toyota   29995
# 5       Honda   23600
# 6      Nissan   61500
# 7  Mitsubishi   58900

# %% [markdown]
# #####Merging two data frames using the following condition. Create two data frames using the following two Dicts, Merge two data frames, and append the second data frame as a new column to the first data frame.
# #####Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
# #####car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}

# %%
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}
df_price = pd.DataFrame(Car_Price)
df_horsepower = pd.DataFrame(car_Horsepower)
df2= pd.merge(df_price, df_horsepower, on='Company')
print(df2)
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160

# %% [markdown]
# #####Get total profit of all months and show line plot with the following Style properties
# Generated a line plot with the following Style properties: –
# *  Line Style:dotted and Line-color: red
# *  Legend at the lower right location.
# *  X label name = Month Number
# *  Y label name = Sold units number
# *  A circle marker.
# *  Line marker color as read
# *  Line width: 3

# %%
import matplotlib.pyplot as plt
df = pd.read_csv('company_sales_data.csv')
plt.figure(figsize=(10, 6))
plt.plot(df['month_number'], df['total_profit'], linestyle=':', color='red',marker='o',markerfacecolor='red',linewidth=3)
plt.xlabel('Month Number')
plt.ylabel('Sold Units Number')
plt.title('Total Profit vs. Month Number')
plt.legend(['Total Profit'], loc='lower right')
plt.show()

# %% [markdown]
# #####Reading all product sales data and using a multiline plot to visualise it. Displaying the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).

# %%
plt.plot(df['month_number'], df['facecream'], label='Facecream')
plt.plot(df['month_number'], df['facewash'], label='Facewash')
plt.plot(df['month_number'], df['bathingsoap'], label='Bathing Soap')
plt.plot(df['month_number'], df['shampoo'], label='Shampoo')
plt.plot(df['month_number'], df['moisturizer'], label='Moisturizer')
plt.xlabel('Month Number')
plt.ylabel('Units Sold')
plt.legend(loc='best')
plt.show()

# %%
width = 0.35
plt.bar(df['month_number'] - width/2, df['facecream'], width, label='Facecream', color='blue')
plt.bar(df['month_number'] + width/2, df['facewash'], width, label='Facewash', color='green')
plt.xlabel('Month Number')
plt.ylabel('Units Sold')
plt.legend(loc='best')
plt.xticks(df['month_number'])
plt.show()

# %% [markdown]
# Reading all product sales data and showed it using the stack plot

# %%
month=df['month_number']
plt.stackplot(df['month_number'], df['facecream'], df['facewash'], df['toothpaste'], df['bathingsoap'], df['shampoo'], df['moisturizer'],
              labels=['Facecream', 'Facewash', 'Toothpaste', 'Bathing Soap', 'Shampoo', 'Moisturizer'],
              alpha=0.7)
plt.xlabel('Month Number')
plt.ylabel('Units Sold')
plt.xticks(month)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# #####Making a plot of the function f(x)=x^2andg(x)=x^3for−5≤x≤5.

# %%
import seaborn as sns
import numpy as np

sns.set()
x = np.linspace(-5, 5, 100)
f_x = x**2
g_x = x**3
plt.figure(figsize=(10, 6))
plt.plot(x, f_x, color='red', marker='o', label='$f(x) = x^2$')
plt.plot(x, g_x, color='blue', marker='s', label='$g(x) = x^3$')
plt.title('Plot of $f(x) = x^2$ and $g(x) = x^3$', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.legend(loc=10)
plt.xlim(-6, 6)
plt.ylim(-10, 10)
plt.grid(True)
plt.show()

# %% [markdown]
# #####Given the lists x = np.arange(11) and y=x^2, creating a 2 by 3 subplot where each subplot plots x versus y using plot, scatter, bar, loglog, semilogx, and semilogy.

# %%
x = np.arange(11)
y = x**2
fig, axs = plt.subplots(2, 3, figsize=(15, 10))
axs[0, 0].plot(x, y, label="x vs x^2", color='blue')
axs[0, 0].set_title('Plot: x vs x^2')
axs[0, 0].set_xlabel('x')
axs[0, 0].set_ylabel('y')
axs[0, 0].grid(True)

axs[0, 1].scatter(x, y, color='red')
axs[0, 1].set_title('Scatter: x vs x^2')
axs[0, 1].set_xlabel('x')
axs[0, 1].set_ylabel('y')
axs[0, 1].grid(True)

axs[0, 2].bar(x, y, color='green')
axs[0, 2].set_title('Bar: x vs x^2')
axs[0, 2].set_xlabel('x')
axs[0, 2].set_ylabel('y')
axs[0, 2].grid(True)

axs[1, 0].loglog(x, y, color='purple')
axs[1, 0].set_title('Log-Log: x vs x^2')
axs[1, 0].set_xlabel('x')
axs[1, 0].set_ylabel('y')
axs[1, 0].grid(True)

axs[1, 1].semilogx(x, y, color='orange')
axs[1, 1].set_title('Semilogx: x vs x^2')
axs[1, 1].set_xlabel('x')
axs[1, 1].set_ylabel('y')
axs[1, 1].grid(True)

axs[1, 2].semilogy(x, y, color='brown')
axs[1, 2].set_title('Semilogy: x vs x^2')
axs[1, 2].set_xlabel('x')
axs[1, 2].set_ylabel('y')
axs[1, 2].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #####Plotting a 3D figure using the following 2 groups of data. Group1 is coloured green using the marker "o" and Group2 red using the marker "+".
# #####Data for 3D scattered points.
# #Group 1
# ######zdata_group_1=15*np.random.random(100)
# ######xdata_group_1=np.sin(zdata_group_1) + 0.1*np.random.randn(100)
# ######ydata_group_1=np.cos(zdata_group_1) + 0.1*np.random.randn(100)
# #Group 2
# ######zdata_group_2=[10,3,5,8,9,6]
# ######xdata_group_2=[4,9,9,5,10,8]
# ######ydata_group_2=[5,5,2,10,5,3]

# %%
from mpl_toolkits.mplot3d import Axes3D

zdata_group_1 = 15 * np.random.random(100)
xdata_group_1 = np.sin(zdata_group_1) + 0.1 * np.random.randn(100)
ydata_group_1 = np.cos(zdata_group_1) + 0.1 * np.random.randn(100)

zdata_group_2 = [10, 3, 5, 8, 9, 6]
xdata_group_2 = [4, 9, 9, 5, 10, 8]
ydata_group_2 = [5, 5, 2, 10, 5, 3]

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xdata_group_1, ydata_group_1, zdata_group_1, color='green', marker='o', label='Group 1')
ax.scatter(xdata_group_2, ydata_group_2, zdata_group_2, color='red', marker='+', label='Group 2')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
ax.set_title('3D Scatter Plot of Two Groups')
ax.legend()
plt.show()

# %% [markdown]
# #####The function to plot the 3D surfaces is plot_surface(X,Y,Z), where X and Y are the output arrays from meshgrid, and Z=f(X,Y) or Z(i,j)=f(X(i,j),Y(i,j)). The most common surface plotting functions are surf and contour.
# #####Plotting of the surface f(x,y)=sin(x)⋅cos(y)for−5≤x≤5,−5≤y≤5 using the plot_surface function.

# %%
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)

fig = plt.figure(figsize=(12,6))

ax1 = fig.add_subplot(121, projection='3d')
contour = ax1.contour(X, Y, Z, cmap='viridis')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')

ax2 = fig.add_subplot(122, projection='3d')
ax2.plot_surface(X, Y, Z, cmap='viridis')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')

plt.tight_layout()
plt.show()
